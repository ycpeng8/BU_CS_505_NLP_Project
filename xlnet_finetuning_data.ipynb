# %%
# for SCC jupyter
# import os
# os.environ["WANDB_DISABLED"] = "true"

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
root_path = '/content/gdrive/My Drive/Common Data/CS505/project/'

# %%
import pandas as pd
import os
# should test if the number of df rows matches the number of txt rows
# some data files meet the problem:  
# such as twitter-2016train-A, should be 6000 examples, but some lines are read as one line

# data_path='./data/'
data_path='/content/gdrive/My Drive/Common Data/CS505/project/Subtask_A/'

train_files=[]
test_files=[]
for file in os.listdir(data_path):
    if file.startswith('twitter') and file.endswith('.txt'):
        temp_path=os.path.join(data_path,file)
        if file=='twitter-2016test-A.txt':
            test_files.append(temp_path)
        else:
            train_files.append(temp_path)

# %%
import nltk
nltk.download('punkt')

df_train=None
length_threshold=150 # number of words in a sentence, try to filter out the wrong read lines
for file in train_files:
    df_temp=pd.read_csv(file,sep='\t',names=['id','sentiment','text','none'])
    for idx, text in enumerate(df_temp.text.values):
        tokens = nltk.word_tokenize(text)
        if len(tokens)>length_threshold:
            df_temp.drop(index=[idx])
    df_train=pd.concat([df_train,df_temp])
df_train=df_train[df_train.sentiment.isin(['negative','positive'])]
df_train
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                       id sentiment  \
# 2     264194578381410304  negative
# 5     263722278712393728  positive
# 6     262936443171778560  positive
# 8     262968617233162240  positive
# 9     263790847424880641  positive
# ...                  ...       ...
# 9678  101450548439560192  negative
# 9679  103158179306807296  positive
# 9680  103157324096618497  positive
# 9682  104230318525001729  positive
# 9683  100461938533863424  negative
#
#                                                    text  none
# 2     @francesco_con40 2nd worst QB. DEFINITELY Tony...   NaN
# 5     Tim Tebow may be availible ! Wow Jerry \u002c ...   NaN
# 6     @mariakaykay aga tayo tomorrow ah. :) Good nig...   NaN
# 8     Lunch from my new Lil spot ...THE COTTON BOWL ...   NaN
# 9     SNC Halloween Pr. Pumped. Let\u2019s work it f...   NaN
# ...                                                 ...   ...
# 9678  @stoney16 @JeffMossDSR I'd recommend just turn...   NaN
# 9679  RT @MNFootNg It's monday and Monday Night Foot...   NaN
# 9680  All I know is the road for that Lomardi start ...   NaN
# 9682  @DariusButler28   Have a great game agaist Tam...   NaN
# 9683  I'm pisseeedddd that I missed Kid Cudi's show ...   NaN
#
# [17318 rows x 4 columns]

# %%
df_test=None
length_threshold=150 # number of words in a sentence, try to filter out the wrong read lines
for file in test_files:
    df_temp=pd.read_csv(file,sep='\t',names=['id','sentiment','text','none'])
    for idx, text in enumerate(df_temp.text.values):
        tokens = nltk.word_tokenize(text)
        if len(tokens)>length_threshold:
            df_temp.drop(index=[idx])
    df_test=pd.concat([df_test,df_temp])
df_test=df_test[df_test.sentiment.isin(['negative','positive'])]
df_test
# should be 20633 rows, but get 20632 (?)
# Out:
#                        id sentiment  \
# 2      619971047195045888  negative
# 4      619987808317407232  positive
# 5      619994586182619136  positive
# 6      619998879447162881  positive
# 8      620013074272137216  positive
# ...                   ...       ...
# 20617  681820700592701440  positive
# 20619  681827597962096641  positive
# 20620  681828714376749057  positive
# 20628  681879579129200640  positive
# 20630  681904976860327936  negative
#
#                                                     text none
# 2      If these runway renovations at the airport pre...  NaN
# 4      A portion of book sales from our Harper Lee/Go...  NaN
# 5      Excited to read "Go Set a Watchman" on Tuesday...  NaN
# 6      Watching Miss USA tomorrow JUST to see @Travis...  NaN
# 8      Call for reservations for lunch or dinner tomo...  NaN
# ...                                                  ...  ...
# 20617  @viagogo hiya, do you know when my tickets for...  NaN
# 20619  @PurposeTourCom Selling 4 Justin bieber standi...  NaN
# 20620  @Chidwack__ omg yes!! Then I'll be in Milan fo...  NaN
# 20628  Iran ranks 1st in liver surgeries, Allah bless...  NaN
# 20630  @VanityFair  Alex Kim Kardashian worth how to ...  NaN
#
# [10290 rows x 4 columns]

# %%
train_texts=df_train.text.values
train_sentiments=df_train.sentiment.values

# %%
test_texts=df_test.text.values
test_sentiments=df_test.sentiment.values

# %%
sent2labels={'negative':0, 'positive':1}
train_labels=[sent2labels[x] for x in train_sentiments]

# %%
test_labels=[sent2labels[x] for x in test_sentiments]

# %%
df_train.insert(df_train.shape[1],'label',train_labels)
df_train
# Out:
#                       id sentiment  \
# 2     264194578381410304  negative
# 5     263722278712393728  positive
# 6     262936443171778560  positive
# 8     262968617233162240  positive
# 9     263790847424880641  positive
# ...                  ...       ...
# 9678  101450548439560192  negative
# 9679  103158179306807296  positive
# 9680  103157324096618497  positive
# 9682  104230318525001729  positive
# 9683  100461938533863424  negative
#
#                                                    text  none  label
# 2     @francesco_con40 2nd worst QB. DEFINITELY Tony...   NaN      0
# 5     Tim Tebow may be availible ! Wow Jerry \u002c ...   NaN      1
# 6     @mariakaykay aga tayo tomorrow ah. :) Good nig...   NaN      1
# 8     Lunch from my new Lil spot ...THE COTTON BOWL ...   NaN      1
# 9     SNC Halloween Pr. Pumped. Let\u2019s work it f...   NaN      1
# ...                                                 ...   ...    ...
# 9678  @stoney16 @JeffMossDSR I'd recommend just turn...   NaN      0
# 9679  RT @MNFootNg It's monday and Monday Night Foot...   NaN      1
# 9680  All I know is the road for that Lomardi start ...   NaN      1
# 9682  @DariusButler28   Have a great game agaist Tam...   NaN      1
# 9683  I'm pisseeedddd that I missed Kid Cudi's show ...   NaN      0
#
# [17318 rows x 5 columns]

# %%
df_test.insert(df_test.shape[1],'label',test_labels)

# %%
# split the train dataset to train and val with 9:1 ratio
from sklearn.model_selection import train_test_split
df_train_split,df_val_split=train_test_split(df_train[['text','label']], test_size=.1)

# %%
from datasets import Dataset,Features,Value,ClassLabel
class_names = ["negative", "positive"]
sentiment_features = Features({'text': Value('string'), 'label': ClassLabel(names=class_names)})

train_dataset=Dataset.from_pandas(df_train_split[['text','label']],features=sentiment_features)
val_dataset=Dataset.from_pandas(df_val_split[['text','label']],features=sentiment_features)

# %%
test_dataset=Dataset.from_pandas(df_test[['text','label']],features=sentiment_features)

# %%
model_names=["prajjwal1/bert-tiny",'sshleifer/tiny-xlnet-base-cased','gpt2']
model_index=1
model_name=model_names[model_index]

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_name,force_download=True,)

def tokenize_function(examples):
    if model_index==2: # for gpt model
        tokenizer.pad_token = tokenizer.eos_token
    return tokenizer(examples["text"], padding='max_length', truncation=True,max_length=128)

tokenized_train_datasets = train_dataset.map(tokenize_function, batched=True)
tokenized_val_datasets = val_dataset.map(tokenize_function, batched=True)
# Out:
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/728 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/779k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/153 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
#   0%|          | 0/16 [00:00<?, ?ba/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]

# %%
tokenized_test_datasets = test_dataset.map(tokenize_function, batched=True)
# Out:
#   0%|          | 0/11 [00:00<?, ?ba/s]

# %%
len(tokenized_train_datasets[0]['input_ids'])
# Out:
# 128

# %%
from transformers import AutoModelForSequenceClassification

# model init function for hyperparameter search
def model_init():
    return AutoModelForSequenceClassification.from_pretrained(root_path+'noisy_'+model_name+'_model', num_labels=2, return_dict=True)
# init the model for train 
model = AutoModelForSequenceClassification.from_pretrained(root_path+'noisy_'+model_name+'_model', num_labels=2)
if model_index==2: # for gpt model
    model.config.pad_token_id = model.config.eos_token_id
# Out:
# loading configuration file /content/gdrive/My Drive/Common Data/CS505/project/noisy_sshleifer/tiny-xlnet-base-cased_model/config.json
# Model config XLNetConfig {
#   "_name_or_path": "/content/gdrive/My Drive/Common Data/CS505/project/noisy_sshleifer/tiny-xlnet-base-cased_model",
#   "architectures": [
#     "XLNetForSequenceClassification"
#   ],
#   "attn_type": "bi",
#   "bi_data": false,
#   "bos_token_id": 1,
#   "clamp_len": -1,
#   "d_head": 2,
#   "d_inner": 2,
#   "d_model": 4,
#   "dropout": 0.1,
#   "end_n_top": 5,
#   "eos_token_id": 2,
#   "ff_activation": "gelu",
#   "initializer_range": 0.02,
#   "layer_norm_eps": 1e-12,
#   "mem_len": null,
#   "model_type": "xlnet",
#   "n_head": 2,
#   "n_layer": 2,
#   "pad_token_id": 5,
#   "problem_type": "single_label_classification",
#   "reuse_len": null,
#   "same_length": false,
#   "start_n_top": 5,
#   "summary_activation": "tanh",
#   "summary_last_dropout": 0.1,
#   "summary_type": "last",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text_generation": {
#       "max_length": 210
#     }
#   },
#   "torch_dtype": "float32",
#   "transformers_version": "4.18.0",
#   "untie_r": true,
#   "use_mems_eval": true,
#   "use_mems_train": false,
#   "vocab_size": 32000
# }
#
# loading weights file /content/gdrive/My Drive/Common Data/CS505/project/noisy_sshleifer/tiny-xlnet-base-cased_model/pytorch_model.bin
# All model checkpoint weights were used when initializing XLNetForSequenceClassification.
#
# All the weights of XLNetForSequenceClassification were initialized from the model checkpoint at /content/gdrive/My Drive/Common Data/CS505/project/noisy_sshleifer/tiny-xlnet-base-cased_model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use XLNetForSequenceClassification for predictions without further training.

# %%
import numpy as np
from datasets import load_metric

metric = load_metric("accuracy")
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

# %%
from transformers import TrainingArguments,Trainer


training_args = TrainingArguments(output_dir='/content/gdrive/My Drive/Common Data/CS505/project/'+ 'clean_finetuning_'+model_name+'_ckpt',
                                  learning_rate=9e-5,
                                  weight_decay=0.01,
                                  warmup_ratio=0.3,
                                  per_device_train_batch_size=16,
                                  per_device_eval_batch_size=32,
                                  num_train_epochs=5,
                                  evaluation_strategy="epoch",
                                 )
trainer = Trainer(
    model=model, # for train
    # model_init=model_init, # for hyperparas search
    args=training_args,
    train_dataset=tokenized_train_datasets,
    eval_dataset=tokenized_val_datasets,
    compute_metrics=compute_metrics,
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
## Code use to search to best hyperparameters
# single gpu, use optuna as backend (use pip install optuna)

############## not used now ###############
# def my_hp_space(trial):
#     return {
#         "learning_rate": trial.suggest_float("learning_rate", [5e-5, 3e-5, 2e-5, 2e-4], log=True),
#         "num_train_epochs": trial.suggest_int("num_train_epochs", [1,3, 5]),
#         "seed": trial.suggest_int("seed", 1, 40),
#         "per_device_train_batch_size": trial.suggest_categorical("per_device_train_batch_size", [4, 8, 16, 32, 64]),
#     }
# trainer.hyperparameter_search(
#     direction="maximize", 
#     backend="optuna", 
#     hp_space=my_hp_space,
# )

# %%
trainer.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `XLNetForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLNetForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 15586
#   Num Epochs = 5
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 4875
#     <div>
#
#       <progress value='4875' max='4875' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4875/4875 01:40, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.545200</td>
#       <td>0.508900</td>
#       <td>0.775982</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.503200</td>
#       <td>0.472707</td>
#       <td>0.797344</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.459000</td>
#       <td>0.440272</td>
#       <td>0.812356</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.421300</td>
#       <td>0.431879</td>
#       <td>0.815820</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.403200</td>
#       <td>0.432830</td>
#       <td>0.821016</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-500/pytorch_model.bin
# The following columns in the evaluation set  don't have a corresponding argument in `XLNetForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLNetForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1732
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-1000
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-1000/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-1000/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-1500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-1500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-1500/pytorch_model.bin
# The following columns in the evaluation set  don't have a corresponding argument in `XLNetForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLNetForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1732
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-2000
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-2000/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-2000/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-2500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-2500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-2500/pytorch_model.bin
# The following columns in the evaluation set  don't have a corresponding argument in `XLNetForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLNetForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1732
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-3000
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-3000/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-3000/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-3500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-3500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-3500/pytorch_model.bin
# The following columns in the evaluation set  don't have a corresponding argument in `XLNetForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLNetForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1732
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-4000
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-4000/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-4000/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-4500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-4500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_ckpt/checkpoint-4500/pytorch_model.bin
# The following columns in the evaluation set  don't have a corresponding argument in `XLNetForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLNetForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1732
#   Batch size = 32
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=4875, training_loss=0.4629000901442308, metrics={'train_runtime': 100.9093, 'train_samples_per_second': 772.278, 'train_steps_per_second': 48.311, 'total_flos': 18553574400.0, 'train_loss': 0.4629000901442308, 'epoch': 5.0})

# %%
# trainer.evaluate(tokenized_train_datasets)

# %%
# trainer.evaluate(tokenized_val_datasets)

# %%
trainer.evaluate(tokenized_test_datasets)
# Out:
# The following columns in the evaluation set  don't have a corresponding argument in `XLNetForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLNetForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 10290
#   Batch size = 32
#     <div>
#
#       <progress value='322' max='322' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [322/322 00:04]
#     </div>
# {'epoch': 5.0,
#  'eval_accuracy': 0.7838678328474247,
#  'eval_loss': 0.49936556816101074,
#  'eval_runtime': 4.4567,
#  'eval_samples_per_second': 2308.894,
#  'eval_steps_per_second': 72.251}

# %%
trainer.save_model(root_path+ 'clean_finetuning_'+model_name+'_model')
# Out:
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_model
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_model/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/clean_finetuning_sshleifer/tiny-xlnet-base-cased_model/pytorch_model.bin

# %%
training_loss = [0.545200, 0.503200, 0.459000, 0.421300, 0.403200]
validation_loss = [0.508900, 0.472707, 0.440272, 0.431879, 0.432830]

# %%
import matplotlib.pyplot as plt
% matplotlib inline

import seaborn as sns

# Use plot styling from seaborn.
sns.set(style='darkgrid')

# Increase the plot size and font size.
sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)

# Plot the learning curve.
plt.plot([1,2,3,4,5], training_loss, 'b-o', label="Training")
plt.plot([1,2,3,4,5], validation_loss, 'g-o', label="Validation")

# Label the plot.
plt.title("xlnet-tiny finetuning model (Training & Validation Loss)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.xticks([1, 2, 3, 4, 5])

plt.show()

# %%
# access the training history to plot the loss graph
# trainer.state.log_history

# %%
# model = AutoModelForSequenceClassification.from_pretrained(model_name+'/checkpoint-1000', num_labels=3)

# %%
# trainer = Trainer(
#     model=model, # for train
#     # model_init=model_init, # for hyperparas search
#     args=training_args,
#     train_dataset=tokenized_train_datasets,
#     eval_dataset=tokenized_val_datasets,
#     compute_metrics=compute_metrics,
# )

# %%
# trainer.state.log_history

# %%
# trainer.evaluate(tokenized_test_datasets)
