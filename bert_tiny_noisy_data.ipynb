# %% [markdown]
# # Bert-tiny model trained on the noisy data

# %%
# for SCC jupyter
import os
os.environ["WANDB_DISABLED"] = "true"

# %%
# for google colab
from google.colab import drive
drive.mount('/content/gdrive')

# %%
import pandas as pd
import os
# should test if the number of df rows matches the number of txt rows
# some data files meet the problem:  
# such as twitter-2016train-A, should be 6000 examples, but some lines are read as one line

# data_path='./data/'
# train_file='./data/training.1600000.processed.noemoticon.csv'
# test_file='./data/twitter-2016test-A.txt'

# %%
root_path = '/content/gdrive/My Drive/Common Data/CS505/project/'
train_file='/content/gdrive/My Drive/Common Data/CS505/project/training.1600000.processed.noemoticon.csv'
test_file='/content/gdrive/My Drive/Common Data/CS505/project/Subtask_A/twitter-2016test-A.txt'

# %% [markdown]
# ## 1. Import the data

# %% [markdown]
# ### 1.1 Import the training data

# %%
df_train=pd.read_csv(train_file,sep=',',names=['sentiment','id','time','no_query','user','text'])
df_train
# Out:
#          sentiment          id                          time  no_query  \
# 0                0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1                0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2                0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3                0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4                0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...            ...         ...                           ...       ...
# 1599995          4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996          4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997          4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998          4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999          4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# 0        _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          scotthamilton  is upset that he can't update his Facebook by ...
# 2               mattycus  @Kenichan I dived many times for the ball. Man...
# 3                ElleCTF    my whole body feels itchy and like its on fire
# 4                 Karoli  @nationwideclass no, it's not behaving at all....
# ...                  ...                                                ...
# 1599995  AmandaMarie1028  Just woke up. Having no school is the best fee...
# 1599996      TheWDBoards  TheWDB.com - Very cool to hear old Walt interv...
# 1599997           bpbabe  Are you ready for your MoJo Makeover? Ask me f...
# 1599998     tinydiamondz  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999   RyanTrevMorris  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1600000 rows x 6 columns]

# %% [markdown]
# ### 1.2 Import the test data

# %%
import nltk
nltk.download('punkt')
df_test=None
length_threshold=150 # number of words in a sentence, try to filter out the wrong read lines

df_test=pd.read_csv(test_file,sep='\t',names=['id','sentiment','text','none'])
for idx, text in enumerate(df_test.text.values):
    tokens = nltk.word_tokenize(text)
    if len(tokens)>length_threshold:
        df_test.drop(index=[idx])
df_test=df_test[df_test.sentiment.isin(['negative','positive'])]
df_test
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                        id sentiment  \
# 2      619971047195045888  negative
# 4      619987808317407232  positive
# 5      619994586182619136  positive
# 6      619998879447162881  positive
# 8      620013074272137216  positive
# ...                   ...       ...
# 20617  681820700592701440  positive
# 20619  681827597962096641  positive
# 20620  681828714376749057  positive
# 20628  681879579129200640  positive
# 20630  681904976860327936  negative
#
#                                                     text none
# 2      If these runway renovations at the airport pre...  NaN
# 4      A portion of book sales from our Harper Lee/Go...  NaN
# 5      Excited to read "Go Set a Watchman" on Tuesday...  NaN
# 6      Watching Miss USA tomorrow JUST to see @Travis...  NaN
# 8      Call for reservations for lunch or dinner tomo...  NaN
# ...                                                  ...  ...
# 20617  @viagogo hiya, do you know when my tickets for...  NaN
# 20619  @PurposeTourCom Selling 4 Justin bieber standi...  NaN
# 20620  @Chidwack__ omg yes!! Then I'll be in Milan fo...  NaN
# 20628  Iran ranks 1st in liver surgeries, Allah bless...  NaN
# 20630  @VanityFair  Alex Kim Kardashian worth how to ...  NaN
#
# [10290 rows x 4 columns]

# %% [markdown]
# ## 2. Preprocess the data

# %% [markdown]
# ### 2.1 Add the sentiment label to the training data
# If the sentiment is 4, then its label is 1, i.e. the positive one. Otherwise, 0.

# %%
train_texts=df_train.text.values
train_sentiments=df_train.sentiment.values
train_labels=[int(x/4) for x in train_sentiments]
df_train.insert(df_train.shape[1],'label',train_labels)
df_train
# Out:
#          sentiment          id                          time  no_query  \
# 0                0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1                0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2                0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3                0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4                0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...            ...         ...                           ...       ...
# 1599995          4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996          4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997          4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998          4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999          4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text  \
# 0        _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          scotthamilton  is upset that he can't update his Facebook by ...
# 2               mattycus  @Kenichan I dived many times for the ball. Man...
# 3                ElleCTF    my whole body feels itchy and like its on fire
# 4                 Karoli  @nationwideclass no, it's not behaving at all....
# ...                  ...                                                ...
# 1599995  AmandaMarie1028  Just woke up. Having no school is the best fee...
# 1599996      TheWDBoards  TheWDB.com - Very cool to hear old Walt interv...
# 1599997           bpbabe  Are you ready for your MoJo Makeover? Ask me f...
# 1599998     tinydiamondz  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999   RyanTrevMorris  happy #charitytuesday @theNSPCC @SparksCharity...
#
#          label
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 1599995      1
# 1599996      1
# 1599997      1
# 1599998      1
# 1599999      1
#
# [1600000 rows x 7 columns]

# %% [markdown]
# ### 2.2 Delete the neutral twitters from the test data. Only keep the positive and negative ones.

# %%
test_texts=df_test.text.values
test_sentiments=df_test.sentiment.values
sent2labels={'negative':0,'positive':1}
test_labels=[sent2labels[x] for x in test_sentiments]
df_test.insert(df_test.shape[1],'label',test_labels)

# %% [markdown]
# ### 2.3 Split the validation datasets with 9:1 ratio

# %%
# split the train dataset to train and val with 9:1 ratio
from sklearn.model_selection import train_test_split
df_train_split,df_val_split=train_test_split(df_train[['text','label']], test_size=.1)

# %% [markdown]
# ### 2.4 Create the dataset of the training, validation and test data

# %%
from datasets import Dataset,Features,Value,ClassLabel
class_names = ["negative", "positive"]
sentiment_features = Features({'text': Value('string'), 'label': ClassLabel(names=class_names)})

train_dataset=Dataset.from_pandas(df_train_split[['text','label']],features=sentiment_features)
val_dataset=Dataset.from_pandas(df_val_split[['text','label']],features=sentiment_features)
test_dataset=Dataset.from_pandas(df_test[['text','label']],features=sentiment_features)

# %% [markdown]
# ### 2.5 Select the model

# %%
model_names=['prajjwal1/bert-tiny', 'sshleifer/tiny-xlnet-base-cased', 'distilgpt2']
model_index=0
model_name=model_names[model_index]

# %% [markdown]
# ### 2.6 Tokenize the data

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_name,force_download=True,)

def tokenize_function(examples):
    if model_name=='distilgpt2': # for gpt model
        tokenizer.pad_token = tokenizer.eos_token
    return tokenizer(examples["text"], padding='max_length', truncation=True,max_length=128)

tokenized_train_datasets = train_dataset.map(tokenize_function, batched=True)
tokenized_val_datasets = val_dataset.map(tokenize_function, batched=True)
tokenized_test_datasets = test_dataset.map(tokenize_function, batched=True)

# %% [markdown]
# ## 3. Train the model

# %% [markdown]
# ### 3.1 Create the model

# %%
from transformers import AutoModelForSequenceClassification

# model init function for hyperparameter search
def model_init():
    return AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2, return_dict=True)
# init the model for train 
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)
if model_name=='distilgpt2': # for gpt model
    model.config.pad_token_id = model.config.eos_token_id

# %% [markdown]
# ### 3.2 Create the metric generator

# %%
import numpy as np
from datasets import load_metric

metric = load_metric("accuracy")
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

# %% [markdown]
# ### 3.3 Configure the training parameters

# %%
from transformers import TrainingArguments,Trainer

training_args = TrainingArguments(output_dir='/content/gdrive/My Drive/Common Data/CS505/project/'+ 'noisy_'+model_name+'_ckpt',
                                  learning_rate=3e-5,
                                  weight_decay=0.01,
                                  warmup_ratio=0.3,
                                  per_device_train_batch_size=512,
                                  per_device_eval_batch_size=512,
                                  num_train_epochs=5,
                                  evaluation_strategy="epoch"
                                 )
trainer = Trainer(
    model=model, # for train
    # model_init=model_init, # for hyperparas search
    args=training_args,
    train_dataset=tokenized_train_datasets,
    eval_dataset=tokenized_val_datasets,
    compute_metrics=compute_metrics,
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %% [markdown]
# ### 3.4 Train

# %%
trainer.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 1440000
#   Num Epochs = 5
#   Instantaneous batch size per device = 512
#   Total train batch size (w. parallel, distributed & accumulation) = 512
#   Gradient Accumulation steps = 1
#   Total optimization steps = 14065
#     <div>
#
#       <progress value='14065' max='14065' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14065/14065 42:59, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.456200</td>
#       <td>0.430508</td>
#       <td>0.800462</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.427100</td>
#       <td>0.409202</td>
#       <td>0.811650</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.416200</td>
#       <td>0.399582</td>
#       <td>0.816987</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.407400</td>
#       <td>0.395497</td>
#       <td>0.819531</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.403500</td>
#       <td>0.394097</td>
#       <td>0.820325</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-500/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-1000
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-1000/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-1000/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-1500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-1500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-1500/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-2000
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-2000/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-2000/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-2500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-2500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-2500/pytorch_model.bin
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 160000
#   Batch size = 512
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-3000
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-3000/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-3000/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-3500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-3500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-3500/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-4000
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-4000/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-4000/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-4500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-4500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-4500/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-5000
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-5000/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-5000/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-5500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-5500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-5500/pytorch_model.bin
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 160000
#   Batch size = 512
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-6000
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-6000/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-6000/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-6500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-6500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-6500/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-7000
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-7000/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-7000/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-7500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-7500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-7500/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-8000
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-8000/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-8000/pytorch_model.bin
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 160000
#   Batch size = 512
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-8500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-8500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-8500/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-9000
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-9000/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-9000/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-9500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-9500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-9500/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-10000
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-10000/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-10000/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-10500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-10500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-10500/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-11000
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-11000/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-11000/pytorch_model.bin
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 160000
#   Batch size = 512
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-11500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-11500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-11500/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-12000
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-12000/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-12000/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-12500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-12500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-12500/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-13000
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-13000/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-13000/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-13500
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-13500/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-13500/pytorch_model.bin
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-14000
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-14000/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_ckpt/checkpoint-14000/pytorch_model.bin
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 160000
#   Batch size = 512
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=14065, training_loss=0.42647045595214494, metrics={'train_runtime': 2579.5847, 'train_samples_per_second': 2791.147, 'train_steps_per_second': 5.452, 'total_flos': 2286876672000000.0, 'train_loss': 0.42647045595214494, 'epoch': 5.0})

# %% [markdown]
# ## 4. Test and evaluate the model

# %% [markdown]
# ### 4.1 Calculate the loss and accuracy of the model on the test data

# %%
trainer.evaluate(tokenized_test_datasets)
# Out:
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 10290
#   Batch size = 512
#     <div>
#
#       <progress value='21' max='21' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [21/21 00:02]
#     </div>
# {'epoch': 5.0,
#  'eval_accuracy': 0.750728862973761,
#  'eval_loss': 0.5067750811576843,
#  'eval_runtime': 2.6241,
#  'eval_samples_per_second': 3921.414,
#  'eval_steps_per_second': 8.003}

# %% [markdown]
# ### 4.2 Save the model

# %%
trainer.save_model('/content/gdrive/My Drive/Common Data/CS505/project/'+'noisy_'+model_name+'_model')
# Out:
# Saving model checkpoint to /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_model
# Configuration saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_model/config.json
# Model weights saved in /content/gdrive/My Drive/Common Data/CS505/project/noisy_prajjwal1/bert-tiny_model/pytorch_model.bin

# %% [markdown]
# ### 4.3 Plot

# %%
training_loss = [0.456200, 0.427100, 0.416200, 0.407400, 0.403500]
validation_loss = [0.430508, 0.409202, 0.399582, 0.395497, 0.394097]

# %%
import matplotlib.pyplot as plt
% matplotlib inline

import seaborn as sns

# Use plot styling from seaborn.
sns.set(style='darkgrid')

# Increase the plot size and font size.
sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)

# Plot the learning curve.
plt.plot([1,2,3,4,5], training_loss, 'b-o', label="Training")
plt.plot([1,2,3,4,5], validation_loss, 'g-o', label="Validation")

# Label the plot.
plt.title("Bert-tiny trained on noisy data (Training & Validation Loss)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.xticks([1, 2, 3, 4, 5])

plt.show()
